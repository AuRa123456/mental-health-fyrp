# %% [markdown]
# <style>
#   .model-block { background: var(--color-background-primary); border: 0.5px solid var(--color-border-tertiary); border-radius: var(--border-radius-lg); overflow: hidden; margin-bottom: 1rem; }
#   .model-header { display: flex; align-items: center; gap: 10px; padding: 12px 16px; background: var(--color-background-secondary); border-bottom: 0.5px solid var(--color-border-tertiary); }
#   .model-name { font-size: 14px; font-weight: 500; color: var(--color-text-primary); }
#   .model-dot { width: 8px; height: 8px; border-radius: 50%; flex-shrink: 0; }
#   .rf-dot { background: #3B8BD4; }
#   .xgb-dot { background: #1D9E75; }
#   .svm-dot { background: #7F77DD; }
#   .fold-row { display: grid; grid-template-columns: 110px 1fr 1fr; align-items: center; gap: 12px; padding: 10px 16px; border-bottom: 0.5px solid var(--color-border-tertiary); }
#   .fold-row:last-child { border-bottom: none; }
#   .fold-label { font-size: 12px; color: var(--color-text-secondary); font-weight: 500; }
#   .metric-value { font-size: 13px; font-weight: 500; color: var(--color-text-primary); font-variant-numeric: tabular-nums; }
#   .bar-container { display: flex; align-items: center; gap: 8px; margin-top: 4px; }
#   .bar-track { flex: 1; height: 4px; background: var(--color-border-tertiary); border-radius: 2px; overflow: hidden; }
#   .bar-fill { height: 100%; border-radius: 2px; }
#   .rf-bar  { background: #3B8BD4; }
#   .xgb-bar { background: #1D9E75; }
#   .svm-bar { background: #7F77DD; }
#   .na-tag { font-size: 11px; color: var(--color-text-tertiary); background: var(--color-background-secondary); border: 0.5px solid var(--color-border-tertiary); border-radius: 4px; padding: 1px 6px; display: inline-block; }
#   .header-row { display: grid; grid-template-columns: 110px 1fr 1fr; gap: 12px; padding: 6px 16px; }
#   .col-head { font-size: 10px; color: var(--color-text-tertiary); letter-spacing: 0.05em; text-transform: uppercase; }
# </style>
#
# <div style="padding: 1rem 0;">
#   <div style="font-size: 18px; font-weight: 500; color: var(--color-text-primary); margin-bottom: 0.25rem;">Audio only</div>
#   <div style="font-size: 13px; color: var(--color-text-secondary); margin-bottom: 1.75rem;">Model evaluation — accuracy & ROC-AUC</div>
#
#   <!-- Random Forest -->
#   <div class="model-block">
#     <div class="model-header">
#       <span class="model-dot rf-dot"></span>
#       <span class="model-name">Random Forest</span>
#     </div>
#     <div class="header-row">
#       <span class="col-head">Folds</span>
#       <span class="col-head">Accuracy</span>
#       <span class="col-head">ROC-AUC</span>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">0 folds</span>
#       <span class="na-tag">N/A</span>
#       <div>
#         <div class="metric-value">0.45555555555555555</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:45.56%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">5 folds</span>
#       <div>
#         <div class="metric-value">0.6950738916256158</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:69.51%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.5903654970760234</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:59.04%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">10 folds</span>
#       <div>
#         <div class="metric-value">0.6661904761904762</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:66.62%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.6209999999999999</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:62.10%"></div></div></div>
#       </div>
#     </div>
#   </div>
#
#   <!-- XGBoost -->
#   <div class="model-block">
#     <div class="model-header">
#       <span class="model-dot xgb-dot"></span>
#       <span class="model-name">XGBoost</span>
#     </div>
#     <div class="header-row">
#       <span class="col-head">Folds</span>
#       <span class="col-head">Accuracy</span>
#       <span class="col-head">ROC-AUC</span>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">0 folds</span>
#       <span class="na-tag">N/A</span>
#       <div>
#         <div class="metric-value">0.5055555555555555</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:50.56%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">5 folds</span>
#       <div>
#         <div class="metric-value">0.6315270935960591</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:63.15%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.5707602339181287</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:57.08%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">10 folds</span>
#       <div>
#         <div class="metric-value">0.6814285714285715</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:68.14%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.6491111111111112</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:64.91%"></div></div></div>
#       </div>
#     </div>
#   </div>
#
#   <!-- SVM -->
#   <div class="model-block">
#     <div class="model-header">
#       <span class="model-dot svm-dot"></span>
#       <span class="model-name">SVM</span>
#     </div>
#     <div class="header-row">
#       <span class="col-head">Folds</span>
#       <span class="col-head">Accuracy</span>
#       <span class="col-head">ROC-AUC</span>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">0 folds</span>
#       <span class="na-tag">N/A</span>
#       <div>
#         <div class="metric-value">0.5388888888888889</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:53.89%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">5 folds</span>
#       <div>
#         <div class="metric-value">0.7091133004926109</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:70.91%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.6311330409356726</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:63.11%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">10 folds</span>
#       <div>
#         <div class="metric-value">0.6885714285714286</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:68.86%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.6525</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:65.25%"></div></div></div>
#       </div>
#     </div>
#   </div>
#
#   <div style="font-size: 11px; color: var(--color-text-tertiary); margin-top: 0.5rem;">0-fold rows report ROC-AUC only.</div>
# </div>

# %% [markdown]
# Random Forest -
# 0 Folds - ROC-AUC Score: 0.4361111111111111
# 5 Folds - Average Accuracy: 0.7236453201970443 | Average ROC-AUC: 0.6274305555555555
# 10 Folds - Average Accuracy: 0.6947619047619048 | Average ROC-AUC: 0.6416111111111111
# XGBoost -
# 0 Folds - ROC-AUC Score: 0.5
# 5 Folds - Average Accuracy: 0.6665024630541871 | Average ROC-AUC: 0.600248538011696
# 10 Folds - Average Accuracy: 0.6738095238095239 | Average ROC-AUC: 0.6466111111111111
# SVM -
# 0 Folds - ROC-AUC Score: 0.49999999999999994
# 5 Folds - Average Accuracy: 0.6812807881773401 | Average ROC-AUC: 0.6775073099415205
# 10 Folds - Average Accuracy: 0.6666666666666667 | Average ROC-AUC: 0.6497777777777778

# %% [markdown]
# Random Forest

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/audio_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Separate features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Train-Test Split
# =========================
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# =========================
# 4️⃣ Feature Scaling
# =========================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# =========================
# 5️⃣ Random Forest Model
# =========================
model = RandomForestClassifier(
    n_estimators=400,
    class_weight="balanced",
    random_state=42
)

model.fit(X_train, y_train)

# =========================
# 6️⃣ Predictions
# =========================
THRESHOLD = 0.40  # adjust if needed

y_prob = model.predict_proba(X_test)[:, 1]
y_pred = (y_prob > THRESHOLD).astype(int)

print("\nPredicted distribution:", np.bincount(y_pred))
print("Actual distribution:", np.bincount(y_test))

# =========================
# 7️⃣ Evaluation
# =========================
print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

roc = roc_auc_score(y_test, y_prob)
print("ROC-AUC Score:", roc)
# Out:
# Dataset shape: (141, 132)
# Class distribution: [99 42]
#
# Predicted distribution: [23  6]
# Actual distribution: [20  9]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.80      0.74        20
#            1       0.33      0.22      0.27         9
#
#     accuracy                           0.62        29
#    macro avg       0.51      0.51      0.51        29
# weighted avg       0.58      0.62      0.60        29
#
# ROC-AUC Score: 0.4361111111111111

# %% [markdown]
# Random Forest 5 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/audio_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Drop non-numeric columns (like file names, IDs)
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values if any
df = df.dropna()

# Ensure label exists
if "label" not in df.columns:
    raise ValueError("Label column not found! Rename your label column to 'label'.")

# Separate features and labels
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Stratified K-Fold
# =========================
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40  # Lower threshold for better depressed detection

fold = 1

for train_idx, test_idx in skf.split(X, y):

    print(f"\n========== Fold {fold} ==========")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ Random Forest Model
    # =========================
    model = RandomForestClassifier(
        n_estimators=400,
        max_depth=None,
        class_weight="balanced",
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 6️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    print("Predicted distribution:", np.bincount(y_pred))
    print("Actual distribution:", np.bincount(y_test))

    print(classification_report(y_test, y_pred, zero_division=0))

    acc = np.mean(y_pred == y_test)
    roc = roc_auc_score(y_test, y_prob)

    print("Fold Accuracy:", acc)
    print("Fold ROC-AUC:", roc)

    accuracies.append(acc)
    roc_scores.append(roc)

    fold += 1

# =========================
# 7️⃣ Final Results
# =========================
print("\n==============================")
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("==============================")
# Out:
# Dataset shape: (141, 132)
# Class distribution: [99 42]
#
# ========== Fold 1 ==========
# Predicted distribution: [19 10]
# Actual distribution: [20  9]
#               precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77        20
#            1       0.50      0.56      0.53         9
#
#     accuracy                           0.69        29
#    macro avg       0.64      0.65      0.65        29
# weighted avg       0.70      0.69      0.69        29
#
# Fold Accuracy: 0.6896551724137931
# Fold ROC-AUC: 0.6277777777777778
#
# ========== Fold 2 ==========
# Predicted distribution: [25  3]
# Actual distribution: [20  8]
#               precision    recall  f1-score   support
#
#            0       0.72      0.90      0.80        20
#            1       0.33      0.12      0.18         8
#
#     accuracy                           0.68        28
#    macro avg       0.53      0.51      0.49        28
# weighted avg       0.61      0.68      0.62        28
#
# Fold Accuracy: 0.6785714285714286
# Fold ROC-AUC: 0.690625
#
# ========== Fold 3 ==========
# Predicted distribution: [23  5]
# Actual distribution: [20  8]
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84        20
#            1       0.60      0.38      0.46         8
#
#     accuracy                           0.75        28
#    macro avg       0.69      0.64      0.65        28
# weighted avg       0.73      0.75      0.73        28
#
# Fold Accuracy: 0.75
# Fold ROC-AUC: 0.640625
#
# ========== Fold 4 ==========
# Predicted distribution: [26  2]
# Actual distribution: [20  8]
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        20
#            1       1.00      0.25      0.40         8
#
#     accuracy                           0.79        28
#    macro avg       0.88      0.62      0.63        28
# weighted avg       0.84      0.79      0.74        28
#
# Fold Accuracy: 0.7857142857142857
# Fold ROC-AUC: 0.678125
#
# ========== Fold 5 ==========
# Predicted distribution: [27  1]
# Actual distribution: [19  9]
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.83        19
#            1       1.00      0.11      0.20         9
#
#     accuracy                           0.71        28
#    macro avg       0.85      0.56      0.51        28
# weighted avg       0.80      0.71      0.62        28
#
# Fold Accuracy: 0.7142857142857143
# Fold ROC-AUC: 0.5
#
# ==============================
# Average Accuracy: 0.7236453201970443
# Average ROC-AUC: 0.6274305555555555
# ==============================

# %% [markdown]
# Random Forest with 10 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/audio_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Drop non-numeric columns (like file names, IDs)
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values if any
df = df.dropna()

# Ensure label exists
if "label" not in df.columns:
    raise ValueError("Label column not found! Rename your label column to 'label'.")

# Separate features and labels
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Stratified K-Fold
# =========================
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40  # Lower threshold for better depressed detection

fold = 1

for train_idx, test_idx in skf.split(X, y):

    print(f"\n========== Fold {fold} ==========")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ Random Forest Model
    # =========================
    model = RandomForestClassifier(
        n_estimators=400,
        max_depth=None,
        class_weight="balanced",
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 6️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    print("Predicted distribution:", np.bincount(y_pred))
    print("Actual distribution:", np.bincount(y_test))

    print(classification_report(y_test, y_pred, zero_division=0))

    acc = np.mean(y_pred == y_test)
    roc = roc_auc_score(y_test, y_prob)

    print("Fold Accuracy:", acc)
    print("Fold ROC-AUC:", roc)

    accuracies.append(acc)
    roc_scores.append(roc)

    fold += 1

# =========================
# 7️⃣ Final Results
# =========================
print("\n==============================")
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("==============================")
# Out:
# Dataset shape: (141, 132)
# Class distribution: [99 42]
#
# ========== Fold 1 ==========
# Predicted distribution: [8 7]
# Actual distribution: [10  5]
#               precision    recall  f1-score   support
#
#            0       0.88      0.70      0.78        10
#            1       0.57      0.80      0.67         5
#
#     accuracy                           0.73        15
#    macro avg       0.72      0.75      0.72        15
# weighted avg       0.77      0.73      0.74        15
#
# Fold Accuracy: 0.7333333333333333
# Fold ROC-AUC: 0.6799999999999999
#
# ========== Fold 2 ==========
# Predicted distribution: [9 5]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.78      0.70      0.74        10
#            1       0.40      0.50      0.44         4
#
#     accuracy                           0.64        14
#    macro avg       0.59      0.60      0.59        14
# weighted avg       0.67      0.64      0.65        14
#
# Fold Accuracy: 0.6428571428571429
# Fold ROC-AUC: 0.6000000000000001
#
# ========== Fold 3 ==========
# Predicted distribution: [12  2]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.75      0.90      0.82        10
#            1       0.50      0.25      0.33         4
#
#     accuracy                           0.71        14
#    macro avg       0.62      0.57      0.58        14
# weighted avg       0.68      0.71      0.68        14
#
# Fold Accuracy: 0.7142857142857143
# Fold ROC-AUC: 0.5
#
# ========== Fold 4 ==========
# Predicted distribution: [12  2]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.75      0.90      0.82        10
#            1       0.50      0.25      0.33         4
#
#     accuracy                           0.71        14
#    macro avg       0.62      0.57      0.58        14
# weighted avg       0.68      0.71      0.68        14
#
# Fold Accuracy: 0.7142857142857143
# Fold ROC-AUC: 0.8
#
# ========== Fold 5 ==========
# Predicted distribution: [9 5]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        10
#            1       0.60      0.75      0.67         4
#
#     accuracy                           0.79        14
#    macro avg       0.74      0.78      0.75        14
# weighted avg       0.81      0.79      0.79        14
#
# Fold Accuracy: 0.7857142857142857
# Fold ROC-AUC: 0.8500000000000001
#
# ========== Fold 6 ==========
# Predicted distribution: [14]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.71        14
#    macro avg       0.36      0.50      0.42        14
# weighted avg       0.51      0.71      0.60        14
#
# Fold Accuracy: 0.7142857142857143
# Fold ROC-AUC: 0.42499999999999993
#
# ========== Fold 7 ==========
# Predicted distribution: [13  1]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.69      0.90      0.78        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.64        14
#    macro avg       0.35      0.45      0.39        14
# weighted avg       0.49      0.64      0.56        14
#
# Fold Accuracy: 0.6428571428571429
# Fold ROC-AUC: 0.575
#
# ========== Fold 8 ==========
# Predicted distribution: [13  1]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.69      0.90      0.78        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.64        14
#    macro avg       0.35      0.45      0.39        14
# weighted avg       0.49      0.64      0.56        14
#
# Fold Accuracy: 0.6428571428571429
# Fold ROC-AUC: 0.7749999999999999
#
# ========== Fold 9 ==========
# Predicted distribution: [13  1]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.69      0.90      0.78        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.64        14
#    macro avg       0.35      0.45      0.39        14
# weighted avg       0.49      0.64      0.56        14
#
# Fold Accuracy: 0.6428571428571429
# Fold ROC-AUC: 0.5
#
# ========== Fold 10 ==========
# Predicted distribution: [11  3]
# Actual distribution: [9 5]
#               precision    recall  f1-score   support
#
#            0       0.73      0.89      0.80         9
#            1       0.67      0.40      0.50         5
#
#     accuracy                           0.71        14
#    macro avg       0.70      0.64      0.65        14
# weighted avg       0.71      0.71      0.69        14
#
# Fold Accuracy: 0.7142857142857143
# Fold ROC-AUC: 0.7111111111111111
#
# ==============================
# Average Accuracy: 0.6947619047619048
# Average ROC-AUC: 0.6416111111111111
# ==============================

# %% [markdown]
# XGBoost

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score
from xgboost import XGBClassifier

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/audio_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Separate features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Train-Test Split
# =========================
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# =========================
# 4️⃣ Feature Scaling
# =========================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# =========================
# 5️⃣ Handle Class Imbalance
# =========================
scale_pos_weight = len(y_train[y_train == 0]) / len(y_train[y_train == 1])

# =========================
# 6️⃣ XGBoost Model
# =========================
model = XGBClassifier(
    n_estimators=300,
    max_depth=4,
    learning_rate=0.05,
    scale_pos_weight=scale_pos_weight,
    eval_metric="logloss",
    random_state=42
)

model.fit(X_train, y_train)

# =========================
# 7️⃣ Predictions
# =========================
THRESHOLD = 0.40  # adjust for better recall

y_prob = model.predict_proba(X_test)[:, 1]
y_pred = (y_prob > THRESHOLD).astype(int)

print("\nPredicted distribution:", np.bincount(y_pred))
print("Actual distribution:", np.bincount(y_test))

# =========================
# 8️⃣ Evaluation
# =========================
print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

roc = roc_auc_score(y_test, y_prob)
print("ROC-AUC Score:", roc)
# Out:
# Dataset shape: (141, 132)
# Class distribution: [99 42]
#
# Predicted distribution: [25  4]
# Actual distribution: [20  9]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.90      0.80        20
#            1       0.50      0.22      0.31         9
#
#     accuracy                           0.69        29
#    macro avg       0.61      0.56      0.55        29
# weighted avg       0.65      0.69      0.65        29
#
# ROC-AUC Score: 0.5

# %% [markdown]
# XGBoost with 5 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score
from xgboost import XGBClassifier

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/audio_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Separate features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Stratified K-Fold Setup
# =========================
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40  # adjust for better recall

fold = 1

for train_idx, test_idx in skf.split(X, y):

    print(f"\n========== Fold {fold} ==========")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ Handle Class Imbalance
    # =========================
    scale_pos_weight = len(y_train[y_train == 0]) / len(y_train[y_train == 1])

    # =========================
    # 6️⃣ XGBoost Model
    # =========================
    model = XGBClassifier(
        n_estimators=500,
        max_depth=5,
        learning_rate=0.05,
        scale_pos_weight=scale_pos_weight,
        eval_metric="logloss",
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 7️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    print("Predicted distribution:", np.bincount(y_pred))
    print("Actual distribution:", np.bincount(y_test))

    print(classification_report(y_test, y_pred, zero_division=0))

    acc = np.mean(y_pred == y_test)
    roc = roc_auc_score(y_test, y_prob)

    print("Fold Accuracy:", acc)
    print("Fold ROC-AUC:", roc)

    accuracies.append(acc)
    roc_scores.append(roc)

    fold += 1

# =========================
# 8️⃣ Final Results
# =========================
print("\n==============================")
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("==============================")
# Out:
# Dataset shape: (141, 132)
# Class distribution: [99 42]
#
# ========== Fold 1 ==========
# Predicted distribution: [19 10]
# Actual distribution: [20  9]
#               precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77        20
#            1       0.50      0.56      0.53         9
#
#     accuracy                           0.69        29
#    macro avg       0.64      0.65      0.65        29
# weighted avg       0.70      0.69      0.69        29
#
# Fold Accuracy: 0.6896551724137931
# Fold ROC-AUC: 0.6055555555555556
#
# ========== Fold 2 ==========
# Predicted distribution: [21  7]
# Actual distribution: [20  8]
#               precision    recall  f1-score   support
#
#            0       0.71      0.75      0.73        20
#            1       0.29      0.25      0.27         8
#
#     accuracy                           0.61        28
#    macro avg       0.50      0.50      0.50        28
# weighted avg       0.59      0.61      0.60        28
#
# Fold Accuracy: 0.6071428571428571
# Fold ROC-AUC: 0.525
#
# ========== Fold 3 ==========
# Predicted distribution: [23  5]
# Actual distribution: [20  8]
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84        20
#            1       0.60      0.38      0.46         8
#
#     accuracy                           0.75        28
#    macro avg       0.69      0.64      0.65        28
# weighted avg       0.73      0.75      0.73        28
#
# Fold Accuracy: 0.75
# Fold ROC-AUC: 0.65625
#
# ========== Fold 4 ==========
# Predicted distribution: [18 10]
# Actual distribution: [20  8]
#               precision    recall  f1-score   support
#
#            0       0.78      0.70      0.74        20
#            1       0.40      0.50      0.44         8
#
#     accuracy                           0.64        28
#    macro avg       0.59      0.60      0.59        28
# weighted avg       0.67      0.64      0.65        28
#
# Fold Accuracy: 0.6428571428571429
# Fold ROC-AUC: 0.60625
#
# ========== Fold 5 ==========
# Predicted distribution: [19  9]
# Actual distribution: [19  9]
#               precision    recall  f1-score   support
#
#            0       0.74      0.74      0.74        19
#            1       0.44      0.44      0.44         9
#
#     accuracy                           0.64        28
#    macro avg       0.59      0.59      0.59        28
# weighted avg       0.64      0.64      0.64        28
#
# Fold Accuracy: 0.6428571428571429
# Fold ROC-AUC: 0.6081871345029239
#
# ==============================
# Average Accuracy: 0.6665024630541871
# Average ROC-AUC: 0.600248538011696
# ==============================

# %% [markdown]
# XGBoost with 10 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score
from xgboost import XGBClassifier

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/audio_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Separate features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Stratified K-Fold Setup
# =========================
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40  # adjust for better recall

fold = 1

for train_idx, test_idx in skf.split(X, y):

    print(f"\n========== Fold {fold} ==========")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ Handle Class Imbalance
    # =========================
    scale_pos_weight = len(y_train[y_train == 0]) / len(y_train[y_train == 1])

    # =========================
    # 6️⃣ XGBoost Model
    # =========================
    model = XGBClassifier(
        n_estimators=500,
        max_depth=5,
        learning_rate=0.05,
        scale_pos_weight=scale_pos_weight,
        eval_metric="logloss",
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 7️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    print("Predicted distribution:", np.bincount(y_pred))
    print("Actual distribution:", np.bincount(y_test))

    print(classification_report(y_test, y_pred, zero_division=0))

    acc = np.mean(y_pred == y_test)
    roc = roc_auc_score(y_test, y_prob)

    print("Fold Accuracy:", acc)
    print("Fold ROC-AUC:", roc)

    accuracies.append(acc)
    roc_scores.append(roc)

    fold += 1

# =========================
# 8️⃣ Final Results
# =========================
print("\n==============================")
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("==============================")
# Out:
# Dataset shape: (141, 132)
# Class distribution: [99 42]
#
# ========== Fold 1 ==========
# Predicted distribution: [7 8]
# Actual distribution: [10  5]
#               precision    recall  f1-score   support
#
#            0       0.86      0.60      0.71        10
#            1       0.50      0.80      0.62         5
#
#     accuracy                           0.67        15
#    macro avg       0.68      0.70      0.66        15
# weighted avg       0.74      0.67      0.68        15
#
# Fold Accuracy: 0.6666666666666666
# Fold ROC-AUC: 0.78
#
# ========== Fold 2 ==========
# Predicted distribution: [11  3]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76        10
#            1       0.33      0.25      0.29         4
#
#     accuracy                           0.64        14
#    macro avg       0.53      0.53      0.52        14
# weighted avg       0.61      0.64      0.63        14
#
# Fold Accuracy: 0.6428571428571429
# Fold ROC-AUC: 0.475
#
# ========== Fold 3 ==========
# Predicted distribution: [10  4]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70        10
#            1       0.25      0.25      0.25         4
#
#     accuracy                           0.57        14
#    macro avg       0.47      0.47      0.47        14
# weighted avg       0.57      0.57      0.57        14
#
# Fold Accuracy: 0.5714285714285714
# Fold ROC-AUC: 0.47500000000000003
#
# ========== Fold 4 ==========
# Predicted distribution: [9 5]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.78      0.70      0.74        10
#            1       0.40      0.50      0.44         4
#
#     accuracy                           0.64        14
#    macro avg       0.59      0.60      0.59        14
# weighted avg       0.67      0.64      0.65        14
#
# Fold Accuracy: 0.6428571428571429
# Fold ROC-AUC: 0.575
#
# ========== Fold 5 ==========
# Predicted distribution: [8 6]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.88      0.70      0.78        10
#            1       0.50      0.75      0.60         4
#
#     accuracy                           0.71        14
#    macro avg       0.69      0.72      0.69        14
# weighted avg       0.77      0.71      0.73        14
#
# Fold Accuracy: 0.7142857142857143
# Fold ROC-AUC: 0.775
#
# ========== Fold 6 ==========
# Predicted distribution: [14]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.71        14
#    macro avg       0.36      0.50      0.42        14
# weighted avg       0.51      0.71      0.60        14
#
# Fold Accuracy: 0.7142857142857143
# Fold ROC-AUC: 0.525
#
# ========== Fold 7 ==========
# Predicted distribution: [11  3]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86        10
#            1       0.67      0.50      0.57         4
#
#     accuracy                           0.79        14
#    macro avg       0.74      0.70      0.71        14
# weighted avg       0.77      0.79      0.78        14
#
# Fold Accuracy: 0.7857142857142857
# Fold ROC-AUC: 0.7749999999999999
#
# ========== Fold 8 ==========
# Predicted distribution: [7 7]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       1.00      0.70      0.82        10
#            1       0.57      1.00      0.73         4
#
#     accuracy                           0.79        14
#    macro avg       0.79      0.85      0.78        14
# weighted avg       0.88      0.79      0.80        14
#
# Fold Accuracy: 0.7857142857142857
# Fold ROC-AUC: 0.75
#
# ========== Fold 9 ==========
# Predicted distribution: [10  4]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70        10
#            1       0.25      0.25      0.25         4
#
#     accuracy                           0.57        14
#    macro avg       0.47      0.47      0.47        14
# weighted avg       0.57      0.57      0.57        14
#
# Fold Accuracy: 0.5714285714285714
# Fold ROC-AUC: 0.625
#
# ========== Fold 10 ==========
# Predicted distribution: [8 6]
# Actual distribution: [9 5]
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71         9
#            1       0.50      0.60      0.55         5
#
#     accuracy                           0.64        14
#    macro avg       0.62      0.63      0.63        14
# weighted avg       0.66      0.64      0.65        14
#
# Fold Accuracy: 0.6428571428571429
# Fold ROC-AUC: 0.7111111111111111
#
# ==============================
# Average Accuracy: 0.6738095238095239
# Average ROC-AUC: 0.6466111111111111
# ==============================

# %% [markdown]
# SVM

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/audio_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Separate features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Train-Test Split
# =========================
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# =========================
# 4️⃣ Feature Scaling (CRITICAL for SVM)
# =========================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# =========================
# 5️⃣ SVM Model
# =========================
model = SVC(
    kernel='rbf',          # non-linear
    C=1.0,                 # regularization
    gamma='scale',         # auto scaling
    probability=True,      # needed for ROC-AUC
    class_weight='balanced',
    random_state=42
)

model.fit(X_train, y_train)

# =========================
# 6️⃣ Predictions
# =========================
THRESHOLD = 0.40  # adjust for better depressed recall

y_prob = model.predict_proba(X_test)[:, 1]
y_pred = (y_prob > THRESHOLD).astype(int)

print("\nPredicted distribution:", np.bincount(y_pred))
print("Actual distribution:", np.bincount(y_test))

# =========================
# 7️⃣ Evaluation
# =========================
print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

roc = roc_auc_score(y_test, y_prob)
print("ROC-AUC Score:", roc)
# Out:
# Dataset shape: (141, 132)
# Class distribution: [99 42]
#
# Predicted distribution: [25  4]
# Actual distribution: [20  9]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.85      0.76        20
#            1       0.25      0.11      0.15         9
#
#     accuracy                           0.62        29
#    macro avg       0.47      0.48      0.45        29
# weighted avg       0.55      0.62      0.57        29
#
# ROC-AUC Score: 0.49999999999999994

# %% [markdown]
# SVM with 5 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/audio_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Separate features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Stratified K-Fold Setup
# =========================
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40  # adjust for better recall

fold = 1

for train_idx, test_idx in skf.split(X, y):

    print(f"\n========== Fold {fold} ==========")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling (VERY IMPORTANT for SVM)
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ SVM Model
    # =========================
    model = SVC(
        kernel='rbf',
        C=1.0,
        gamma='scale',
        probability=True,
        class_weight='balanced',
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 6️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    print("Predicted distribution:", np.bincount(y_pred))
    print("Actual distribution:", np.bincount(y_test))

    print(classification_report(y_test, y_pred, zero_division=0))

    acc = np.mean(y_pred == y_test)
    roc = roc_auc_score(y_test, y_prob)

    print("Fold Accuracy:", acc)
    print("Fold ROC-AUC:", roc)

    accuracies.append(acc)
    roc_scores.append(roc)

    fold += 1

# =========================
# 7️⃣ Final Results
# =========================
print("\n==============================")
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("==============================")
# Out:
# Dataset shape: (141, 132)
# Class distribution: [99 42]
#
# ========== Fold 1 ==========
# Predicted distribution: [23  6]
# Actual distribution: [20  9]
#               precision    recall  f1-score   support
#
#            0       0.70      0.80      0.74        20
#            1       0.33      0.22      0.27         9
#
#     accuracy                           0.62        29
#    macro avg       0.51      0.51      0.51        29
# weighted avg       0.58      0.62      0.60        29
#
# Fold Accuracy: 0.6206896551724138
# Fold ROC-AUC: 0.5444444444444445
#
# ========== Fold 2 ==========
# Predicted distribution: [26  2]
# Actual distribution: [20  8]
#               precision    recall  f1-score   support
#
#            0       0.73      0.95      0.83        20
#            1       0.50      0.12      0.20         8
#
#     accuracy                           0.71        28
#    macro avg       0.62      0.54      0.51        28
# weighted avg       0.66      0.71      0.65        28
#
# Fold Accuracy: 0.7142857142857143
# Fold ROC-AUC: 0.7375
#
# ========== Fold 3 ==========
# Predicted distribution: [25  3]
# Actual distribution: [20  8]
#               precision    recall  f1-score   support
#
#            0       0.72      0.90      0.80        20
#            1       0.33      0.12      0.18         8
#
#     accuracy                           0.68        28
#    macro avg       0.53      0.51      0.49        28
# weighted avg       0.61      0.68      0.62        28
#
# Fold Accuracy: 0.6785714285714286
# Fold ROC-AUC: 0.64375
#
# ========== Fold 4 ==========
# Predicted distribution: [27  1]
# Actual distribution: [20  8]
#               precision    recall  f1-score   support
#
#            0       0.70      0.95      0.81        20
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.68        28
#    macro avg       0.35      0.47      0.40        28
# weighted avg       0.50      0.68      0.58        28
#
# Fold Accuracy: 0.6785714285714286
# Fold ROC-AUC: 0.725
#
# ========== Fold 5 ==========
# Predicted distribution: [27  1]
# Actual distribution: [19  9]
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.83        19
#            1       1.00      0.11      0.20         9
#
#     accuracy                           0.71        28
#    macro avg       0.85      0.56      0.51        28
# weighted avg       0.80      0.71      0.62        28
#
# Fold Accuracy: 0.7142857142857143
# Fold ROC-AUC: 0.736842105263158
#
# ==============================
# Average Accuracy: 0.6812807881773401
# Average ROC-AUC: 0.6775073099415205
# ==============================

# %% [markdown]
# SVM with 10 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/audio_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Separate features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Stratified K-Fold Setup
# =========================
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40  # adjust for better recall

fold = 1

for train_idx, test_idx in skf.split(X, y):

    print(f"\n========== Fold {fold} ==========")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling (VERY IMPORTANT for SVM)
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ SVM Model
    # =========================
    model = SVC(
        kernel='rbf',
        C=1.0,
        gamma='scale',
        probability=True,
        class_weight='balanced',
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 6️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    print("Predicted distribution:", np.bincount(y_pred))
    print("Actual distribution:", np.bincount(y_test))

    print(classification_report(y_test, y_pred, zero_division=0))

    acc = np.mean(y_pred == y_test)
    roc = roc_auc_score(y_test, y_prob)

    print("Fold Accuracy:", acc)
    print("Fold ROC-AUC:", roc)

    accuracies.append(acc)
    roc_scores.append(roc)

    fold += 1

# =========================
# 7️⃣ Final Results
# =========================
print("\n==============================")
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("==============================")
# Out:
# Dataset shape: (141, 132)
# Class distribution: [99 42]
#
# ========== Fold 1 ==========
# Predicted distribution: [9 6]
# Actual distribution: [10  5]
#               precision    recall  f1-score   support
#
#            0       0.78      0.70      0.74        10
#            1       0.50      0.60      0.55         5
#
#     accuracy                           0.67        15
#    macro avg       0.64      0.65      0.64        15
# weighted avg       0.69      0.67      0.67        15
#
# Fold Accuracy: 0.6666666666666666
# Fold ROC-AUC: 0.62
#
# ========== Fold 2 ==========
# Predicted distribution: [11  3]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.64      0.70      0.67        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.50        14
#    macro avg       0.32      0.35      0.33        14
# weighted avg       0.45      0.50      0.48        14
#
# Fold Accuracy: 0.5
# Fold ROC-AUC: 0.4
#
# ========== Fold 3 ==========
# Predicted distribution: [13  1]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        10
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.79        14
#    macro avg       0.88      0.62      0.63        14
# weighted avg       0.84      0.79      0.74        14
#
# Fold Accuracy: 0.7857142857142857
# Fold ROC-AUC: 0.55
#
# ========== Fold 4 ==========
# Predicted distribution: [14]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.71        14
#    macro avg       0.36      0.50      0.42        14
# weighted avg       0.51      0.71      0.60        14
#
# Fold Accuracy: 0.7142857142857143
# Fold ROC-AUC: 0.775
#
# ========== Fold 5 ==========
# Predicted distribution: [14]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.71        14
#    macro avg       0.36      0.50      0.42        14
# weighted avg       0.51      0.71      0.60        14
#
# Fold Accuracy: 0.7142857142857143
# Fold ROC-AUC: 0.8250000000000001
#
# ========== Fold 6 ==========
# Predicted distribution: [14]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.71        14
#    macro avg       0.36      0.50      0.42        14
# weighted avg       0.51      0.71      0.60        14
#
# Fold Accuracy: 0.7142857142857143
# Fold ROC-AUC: 0.5
#
# ========== Fold 7 ==========
# Predicted distribution: [13  1]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.69      0.90      0.78        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.64        14
#    macro avg       0.35      0.45      0.39        14
# weighted avg       0.49      0.64      0.56        14
#
# Fold Accuracy: 0.6428571428571429
# Fold ROC-AUC: 0.65
#
# ========== Fold 8 ==========
# Predicted distribution: [14]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.71        14
#    macro avg       0.36      0.50      0.42        14
# weighted avg       0.51      0.71      0.60        14
#
# Fold Accuracy: 0.7142857142857143
# Fold ROC-AUC: 0.875
#
# ========== Fold 9 ==========
# Predicted distribution: [12  2]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.57        14
#    macro avg       0.33      0.40      0.36        14
# weighted avg       0.48      0.57      0.52        14
#
# Fold Accuracy: 0.5714285714285714
# Fold ROC-AUC: 0.525
#
# ========== Fold 10 ==========
# Predicted distribution: [14]
# Actual distribution: [9 5]
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78         9
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.64        14
#    macro avg       0.32      0.50      0.39        14
# weighted avg       0.41      0.64      0.50        14
#
# Fold Accuracy: 0.6428571428571429
# Fold ROC-AUC: 0.7777777777777778
#
# ==============================
# Average Accuracy: 0.6666666666666667
# Average ROC-AUC: 0.6497777777777778
# ==============================
