# %% [markdown]
# <style>
#   .model-block { background: var(--color-background-primary); border: 0.5px solid var(--color-border-tertiary); border-radius: var(--border-radius-lg); overflow: hidden; margin-bottom: 1rem; }
#   .model-header { display: flex; align-items: center; gap: 10px; padding: 12px 16px; background: var(--color-background-secondary); border-bottom: 0.5px solid var(--color-border-tertiary); }
#   .model-name { font-size: 14px; font-weight: 500; color: var(--color-text-primary); }
#   .model-dot { width: 8px; height: 8px; border-radius: 50%; flex-shrink: 0; }
#   .rf-dot { background: #3B8BD4; }
#   .xgb-dot { background: #1D9E75; }
#   .svm-dot { background: #7F77DD; }
#   .fold-row { display: grid; grid-template-columns: 110px 1fr 1fr; align-items: center; gap: 12px; padding: 10px 16px; border-bottom: 0.5px solid var(--color-border-tertiary); }
#   .fold-row:last-child { border-bottom: none; }
#   .fold-label { font-size: 12px; color: var(--color-text-secondary); font-weight: 500; }
#   .metric-value { font-size: 13px; font-weight: 500; color: var(--color-text-primary); font-variant-numeric: tabular-nums; }
#   .bar-container { display: flex; align-items: center; gap: 8px; margin-top: 4px; }
#   .bar-track { flex: 1; height: 4px; background: var(--color-border-tertiary); border-radius: 2px; overflow: hidden; }
#   .bar-fill { height: 100%; border-radius: 2px; }
#   .rf-bar  { background: #3B8BD4; }
#   .xgb-bar { background: #1D9E75; }
#   .svm-bar { background: #7F77DD; }
#   .na-tag { font-size: 11px; color: var(--color-text-tertiary); background: var(--color-background-secondary); border: 0.5px solid var(--color-border-tertiary); border-radius: 4px; padding: 1px 6px; display: inline-block; }
#   .header-row { display: grid; grid-template-columns: 110px 1fr 1fr; gap: 12px; padding: 6px 16px; }
#   .col-head { font-size: 10px; color: var(--color-text-tertiary); letter-spacing: 0.05em; text-transform: uppercase; }
# </style>
#
# <div style="padding: 1rem 0;">
#   <div style="font-size: 18px; font-weight: 500; color: var(--color-text-primary); margin-bottom: 0.25rem;">Multimodal</div>
#   <div style="font-size: 13px; color: var(--color-text-secondary); margin-bottom: 1.75rem;">Model evaluation — accuracy & ROC-AUC</div>
#
#   <!-- Random Forest -->
#   <div class="model-block">
#     <div class="model-header">
#       <span class="model-dot rf-dot"></span>
#       <span class="model-name">Random Forest</span>
#     </div>
#     <div class="header-row">
#       <span class="col-head">Folds</span>
#       <span class="col-head">Accuracy</span>
#       <span class="col-head">ROC-AUC</span>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">0 folds</span>
#       <span class="na-tag">N/A</span>
#       <div>
#         <div class="metric-value">0.44999999999999996</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:45%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">5 folds</span>
#       <div>
#         <div class="metric-value">0.7093596059113302</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:70.94%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.5658479532163743</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:56.58%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">10 folds</span>
#       <div>
#         <div class="metric-value">0.6957142857142857</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:69.57%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.6120277777777777</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:61.20%"></div></div></div>
#       </div>
#     </div>
#   </div>
#
#   <!-- XGBoost -->
#   <div class="model-block">
#     <div class="model-header">
#       <span class="model-dot xgb-dot"></span>
#       <span class="model-name">XGBoost</span>
#     </div>
#     <div class="header-row">
#       <span class="col-head">Folds</span>
#       <span class="col-head">Accuracy</span>
#       <span class="col-head">ROC-AUC</span>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">0 folds</span>
#       <span class="na-tag">N/A</span>
#       <div>
#         <div class="metric-value">0.4666666666666667</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:46.67%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">5 folds</span>
#       <div>
#         <div class="metric-value">0.7093596059113302</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:70.94%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.5658479532163743</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:56.58%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">10 folds</span>
#       <div>
#         <div class="metric-value">0.6957142857142857</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:69.57%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.6120277777777777</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:61.20%"></div></div></div>
#       </div>
#     </div>
#   </div>
#
#   <!-- SVM -->
#   <div class="model-block">
#     <div class="model-header">
#       <span class="model-dot svm-dot"></span>
#       <span class="model-name">SVM</span>
#     </div>
#     <div class="header-row">
#       <span class="col-head">Folds</span>
#       <span class="col-head">Accuracy</span>
#       <span class="col-head">ROC-AUC</span>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">0 folds</span>
#       <span class="na-tag">N/A</span>
#       <div>
#         <div class="metric-value">0.48333333333333334</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:48.33%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">5 folds</span>
#       <div>
#         <div class="metric-value">0.6600985221674878</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:66.01%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.6500877192982456</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:65.01%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">10 folds</span>
#       <div>
#         <div class="metric-value">0.7028571428571428</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:70.29%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.6625</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:66.25%"></div></div></div>
#       </div>
#     </div>
#   </div>
#
#   <div style="font-size: 11px; color: var(--color-text-tertiary); margin-top: 0.5rem;">0-fold rows report ROC-AUC only.</div>
# </div>

# %% [markdown]
# Random Forest

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/multimodal_features.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Drop non-numeric columns (like participant_id)
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Check label
if "label" not in df.columns:
    raise ValueError("Label column not found!")

# Separate features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Train-Test Split
# =========================
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# =========================
# 4️⃣ Scaling (optional for RF)
# =========================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# =========================
# 5️⃣ Random Forest Model
# =========================
model = RandomForestClassifier(
    n_estimators=400,
    class_weight="balanced",
    random_state=42
)

model.fit(X_train, y_train)

# =========================
# 6️⃣ Predictions
# =========================
THRESHOLD = 0.40

y_prob = model.predict_proba(X_test)[:, 1]
y_pred = (y_prob > THRESHOLD).astype(int)

print("\nPredicted distribution:", np.bincount(y_pred))
print("Actual distribution:", np.bincount(y_test))

# =========================
# 7️⃣ Evaluation
# =========================
print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

roc = roc_auc_score(y_test, y_prob)
print("ROC-AUC Score:", roc)
# Out:
# Dataset shape: (141, 445)
# Class distribution: [99 42]
#
# Predicted distribution: [25  4]
# Actual distribution: [20  9]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.80      0.71        20
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.55        29
#    macro avg       0.32      0.40      0.36        29
# weighted avg       0.44      0.55      0.49        29
#
# ROC-AUC Score: 0.44999999999999996

# %% [markdown]
# Random Forest with 5 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/multimodal_features.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns (removes participant_id etc.)
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Check label
if "label" not in df.columns:
    raise ValueError("Label column not found!")

# Separate features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Stratified 10-Fold Setup
# =========================
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40
fold = 1

for train_idx, test_idx in skf.split(X, y):

    print(f"\n========== Fold {fold} ==========")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ Random Forest Model
    # =========================
    model = RandomForestClassifier(
        n_estimators=400,
        class_weight="balanced",
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 6️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    print("Predicted:", np.bincount(y_pred))
    print("Actual:", np.bincount(y_test))

    print(classification_report(y_test, y_pred, zero_division=0))

    acc = np.mean(y_pred == y_test)
    roc = roc_auc_score(y_test, y_prob)

    print("Fold Accuracy:", acc)
    print("Fold ROC-AUC:", roc)

    accuracies.append(acc)
    roc_scores.append(roc)

    fold += 1

# =========================
# 7️⃣ Final Results
# =========================
print("\n==============================")
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("Std deviation:", np.std(roc_scores))
print("==============================")
# Out:
# Dataset shape: (141, 445)
# Class distribution: [99 42]
#
# ========== Fold 1 ==========
# Predicted: [27  2]
# Actual: [20  9]
#               precision    recall  f1-score   support
#
#            0       0.70      0.95      0.81        20
#            1       0.50      0.11      0.18         9
#
#     accuracy                           0.69        29
#    macro avg       0.60      0.53      0.50        29
# weighted avg       0.64      0.69      0.61        29
#
# Fold Accuracy: 0.6896551724137931
# Fold ROC-AUC: 0.425
#
# ========== Fold 2 ==========
# Predicted: [28]
# Actual: [20  8]
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        20
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.71        28
#    macro avg       0.36      0.50      0.42        28
# weighted avg       0.51      0.71      0.60        28
#
# Fold Accuracy: 0.7142857142857143
# ...

# %% [markdown]
# Random Forest with 10 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/multimodal_features.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns (removes participant_id etc.)
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Check label
if "label" not in df.columns:
    raise ValueError("Label column not found!")

# Separate features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Stratified 10-Fold Setup
# =========================
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40
fold = 1

for train_idx, test_idx in skf.split(X, y):

    print(f"\n========== Fold {fold} ==========")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ Random Forest Model
    # =========================
    model = RandomForestClassifier(
        n_estimators=400,
        class_weight="balanced",
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 6️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    print("Predicted:", np.bincount(y_pred))
    print("Actual:", np.bincount(y_test))

    print(classification_report(y_test, y_pred, zero_division=0))

    acc = np.mean(y_pred == y_test)
    roc = roc_auc_score(y_test, y_prob)

    print("Fold Accuracy:", acc)
    print("Fold ROC-AUC:", roc)

    accuracies.append(acc)
    roc_scores.append(roc)

    fold += 1

# =========================
# 7️⃣ Final Results
# =========================
print("\n==============================")
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("Std deviation:", np.std(roc_scores))
print("==============================")
# Out:
# Dataset shape: (141, 445)
# Class distribution: [99 42]
#
# ========== Fold 1 ==========
# Predicted: [14  1]
# Actual: [10  5]
#               precision    recall  f1-score   support
#
#            0       0.64      0.90      0.75        10
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.60        15
#    macro avg       0.32      0.45      0.38        15
# weighted avg       0.43      0.60      0.50        15
#
# Fold Accuracy: 0.6
# Fold ROC-AUC: 0.28
#
# ========== Fold 2 ==========
# Predicted: [13  1]
# Actual: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.69      0.90      0.78        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.64        14
#    macro avg       0.35      0.45      0.39        14
# weighted avg       0.49      0.64      0.56        14
#
# Fold Accuracy: 0.6428571428571429
# Fold ROC-AUC: 0.525
#
# ...

# %% [markdown]
# XGBoost

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score
from xgboost import XGBClassifier

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/multimodal_features.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================
df = df.select_dtypes(include=["int64", "float64"])
df = df.dropna()

X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Train-Test Split
# =========================
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# =========================
# 4️⃣ Scaling
# =========================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# =========================
# 5️⃣ Handle Class Imbalance
# =========================
scale_pos_weight = len(y_train[y_train == 0]) / len(y_train[y_train == 1])

# =========================
# 6️⃣ XGBoost Model
# =========================
model = XGBClassifier(
    n_estimators=300,
    max_depth=4,
    learning_rate=0.05,
    scale_pos_weight=scale_pos_weight,
    eval_metric="logloss",
    random_state=42
)

model.fit(X_train, y_train)

# =========================
# 7️⃣ Predictions
# =========================
THRESHOLD = 0.40

y_prob = model.predict_proba(X_test)[:, 1]
y_pred = (y_prob > THRESHOLD).astype(int)

# =========================
# 8️⃣ Evaluation
# =========================
print(classification_report(y_test, y_pred, zero_division=0))
print("ROC-AUC Score:", roc_auc_score(y_test, y_prob))
# Out:
# Dataset shape: (141, 445)
# Class distribution: [99 42]
#               precision    recall  f1-score   support
#
#            0       0.65      0.75      0.70        20
#            1       0.17      0.11      0.13         9
#
#     accuracy                           0.55        29
#    macro avg       0.41      0.43      0.42        29
# weighted avg       0.50      0.55      0.52        29
#
# ROC-AUC Score: 0.4666666666666667

# %% [markdown]
# XGBoost with 5 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/multimodal_features.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================
df = df.select_dtypes(include=["int64", "float64"])
df = df.dropna()

X = df.drop("label", axis=1).values
y = df["label"].values

# =========================
# 3️⃣ Stratified 5-Fold
# =========================
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40

for train_idx, test_idx in skf.split(X, y):

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # Scaling
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # Model
    model = RandomForestClassifier(
        n_estimators=400,
        class_weight="balanced",
        random_state=42
    )

    model.fit(X_train, y_train)

    # Predictions
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    # Metrics
    accuracies.append(np.mean(y_pred == y_test))
    roc_scores.append(roc_auc_score(y_test, y_prob))

    print(classification_report(y_test, y_pred, zero_division=0))

# =========================
# 4️⃣ Final Results
# =========================
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("Std deviation:", np.std(roc_scores))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.95      0.81        20
#            1       0.50      0.11      0.18         9
#
#     accuracy                           0.69        29
#    macro avg       0.60      0.53      0.50        29
# weighted avg       0.64      0.69      0.61        29
#
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        20
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.71        28
#    macro avg       0.36      0.50      0.42        28
# weighted avg       0.51      0.71      0.60        28
#
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        20
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.71        28
#    macro avg       0.36      0.50      0.42        28
# ...

# %% [markdown]
# XGBoost with 10 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/multimodal_features.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================
df = df.select_dtypes(include=["int64", "float64"])
df = df.dropna()

X = df.drop("label", axis=1).values
y = df["label"].values

# =========================
# 3️⃣ Stratified 5-Fold
# =========================
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40

for train_idx, test_idx in skf.split(X, y):

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # Scaling
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # Model
    model = RandomForestClassifier(
        n_estimators=400,
        class_weight="balanced",
        random_state=42
    )

    model.fit(X_train, y_train)

    # Predictions
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    # Metrics
    accuracies.append(np.mean(y_pred == y_test))
    roc_scores.append(roc_auc_score(y_test, y_prob))

    print(classification_report(y_test, y_pred, zero_division=0))

# =========================
# 4️⃣ Final Results
# =========================
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("Std deviation:", np.std(roc_scores))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.90      0.75        10
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.60        15
#    macro avg       0.32      0.45      0.38        15
# weighted avg       0.43      0.60      0.50        15
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.90      0.78        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.64        14
#    macro avg       0.35      0.45      0.39        14
# weighted avg       0.49      0.64      0.56        14
#
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        10
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.79        14
#    macro avg       0.88      0.62      0.63        14
# ...

# %% [markdown]
# SVM

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/multimodal_features.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================
df = df.select_dtypes(include=["int64", "float64"])
df = df.dropna()

X = df.drop("label", axis=1).values
y = df["label"].values

# =========================
# 3️⃣ Train-Test Split
# =========================
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# =========================
# 4️⃣ Scaling (CRITICAL for SVM)
# =========================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# =========================
# 5️⃣ SVM Model
# =========================
model = SVC(
    kernel='rbf',
    C=1.0,
    gamma='scale',
    probability=True,
    class_weight='balanced',
    random_state=42
)

model.fit(X_train, y_train)

# =========================
# 6️⃣ Predictions
# =========================
THRESHOLD = 0.40

y_prob = model.predict_proba(X_test)[:, 1]
y_pred = (y_prob > THRESHOLD).astype(int)

# =========================
# 7️⃣ Evaluation
# =========================
print(classification_report(y_test, y_pred, zero_division=0))
print("ROC-AUC Score:", roc_auc_score(y_test, y_prob))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.75      0.71        20
#            1       0.29      0.22      0.25         9
#
#     accuracy                           0.59        29
#    macro avg       0.48      0.49      0.48        29
# weighted avg       0.56      0.59      0.57        29
#
# ROC-AUC Score: 0.48333333333333334

# %% [markdown]
# SVM with 5 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/multimodal_features.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================
df = df.select_dtypes(include=["int64", "float64"])
df = df.dropna()

X = df.drop("label", axis=1).values
y = df["label"].values

# =========================
# 3️⃣ Stratified 5-Fold
# =========================
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40

for train_idx, test_idx in skf.split(X, y):

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling (CRITICAL for SVM)
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ SVM Model
    # =========================
    model = SVC(
        kernel='rbf',
        C=1.0,
        gamma='scale',
        probability=True,
        class_weight='balanced',
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 6️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    # =========================
    # 7️⃣ Metrics
    # =========================
    accuracies.append(np.mean(y_pred == y_test))
    roc_scores.append(roc_auc_score(y_test, y_prob))

    print(classification_report(y_test, y_pred, zero_division=0))

# =========================
# 8️⃣ Final Results
# =========================
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("Std ROC-AUC:", np.std(roc_scores))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.75      0.71        20
#            1       0.29      0.22      0.25         9
#
#     accuracy                           0.59        29
#    macro avg       0.48      0.49      0.48        29
# weighted avg       0.56      0.59      0.57        29
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67        20
#            1       0.33      0.50      0.40         8
#
#     accuracy                           0.57        28
#    macro avg       0.54      0.55      0.53        28
# weighted avg       0.63      0.57      0.59        28
#
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        20
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.71        28
#    macro avg       0.36      0.50      0.42        28
# ...

# %% [markdown]
# SVM with 10 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/multimodal_features.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================
df = df.select_dtypes(include=["int64", "float64"])
df = df.dropna()

X = df.drop("label", axis=1).values
y = df["label"].values

# =========================
# 3️⃣ Stratified 5-Fold
# =========================
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40

for train_idx, test_idx in skf.split(X, y):

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling (CRITICAL for SVM)
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ SVM Model
    # =========================
    model = SVC(
        kernel='rbf',
        C=1.0,
        gamma='scale',
        probability=True,
        class_weight='balanced',
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 6️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    # =========================
    # 7️⃣ Metrics
    # =========================
    accuracies.append(np.mean(y_pred == y_test))
    roc_scores.append(roc_auc_score(y_test, y_prob))

    print(classification_report(y_test, y_pred, zero_division=0))

# =========================
# 8️⃣ Final Results
# =========================
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("Std ROC-AUC:", np.std(roc_scores))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        10
#            1       0.33      0.20      0.25         5
#
#     accuracy                           0.60        15
#    macro avg       0.50      0.50      0.49        15
# weighted avg       0.56      0.60      0.57        15
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.90      0.82        10
#            1       0.50      0.25      0.33         4
#
#     accuracy                           0.71        14
#    macro avg       0.62      0.57      0.58        14
# weighted avg       0.68      0.71      0.68        14
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76        10
#            1       0.33      0.25      0.29         4
#
#     accuracy                           0.64        14
#    macro avg       0.53      0.53      0.52        14
# ...
