# %% [markdown]
# <style>
#   .model-block { background: var(--color-background-primary); border: 0.5px solid var(--color-border-tertiary); border-radius: var(--border-radius-lg); overflow: hidden; margin-bottom: 1rem; }
#   .model-header { display: flex; align-items: center; gap: 10px; padding: 12px 16px; background: var(--color-background-secondary); border-bottom: 0.5px solid var(--color-border-tertiary); }
#   .model-name { font-size: 14px; font-weight: 500; color: var(--color-text-primary); }
#   .model-dot { width: 8px; height: 8px; border-radius: 50%; flex-shrink: 0; }
#   .rf-dot { background: #3B8BD4; }
#   .xgb-dot { background: #1D9E75; }
#   .svm-dot { background: #7F77DD; }
#   .fold-row { display: grid; grid-template-columns: 110px 1fr 1fr; align-items: center; gap: 12px; padding: 10px 16px; border-bottom: 0.5px solid var(--color-border-tertiary); }
#   .fold-row:last-child { border-bottom: none; }
#   .fold-label { font-size: 12px; color: var(--color-text-secondary); font-weight: 500; }
#   .metric-value { font-size: 13px; font-weight: 500; color: var(--color-text-primary); font-variant-numeric: tabular-nums; }
#   .bar-container { display: flex; align-items: center; gap: 8px; margin-top: 4px; }
#   .bar-track { flex: 1; height: 4px; background: var(--color-border-tertiary); border-radius: 2px; overflow: hidden; }
#   .bar-fill { height: 100%; border-radius: 2px; }
#   .rf-bar  { background: #3B8BD4; }
#   .xgb-bar { background: #1D9E75; }
#   .svm-bar { background: #7F77DD; }
#   .na-tag { font-size: 11px; color: var(--color-text-tertiary); background: var(--color-background-secondary); border: 0.5px solid var(--color-border-tertiary); border-radius: 4px; padding: 1px 6px; display: inline-block; }
#   .header-row { display: grid; grid-template-columns: 110px 1fr 1fr; gap: 12px; padding: 6px 16px; }
#   .col-head { font-size: 10px; color: var(--color-text-tertiary); letter-spacing: 0.05em; text-transform: uppercase; }
# </style>
#
# <div style="padding: 1rem 0;">
#   <div style="font-size: 18px; font-weight: 500; color: var(--color-text-primary); margin-bottom: 0.25rem;">Text only</div>
#   <div style="font-size: 13px; color: var(--color-text-secondary); margin-bottom: 1.75rem;">Model evaluation — accuracy & ROC-AUC</div>
#
#   <!-- Random Forest -->
#   <div class="model-block">
#     <div class="model-header">
#       <span class="model-dot rf-dot"></span>
#       <span class="model-name">Random Forest</span>
#     </div>
#     <div class="header-row">
#       <span class="col-head">Folds</span>
#       <span class="col-head">Accuracy</span>
#       <span class="col-head">ROC-AUC</span>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">0 folds</span>
#       <span class="na-tag">N/A</span>
#       <div>
#         <div class="metric-value">0.7333333333333333</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:73.33%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">5 folds</span>
#       <div>
#         <div class="metric-value">0.7310344827586206</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:73.10%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.6904495614035088</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:69.04%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">10 folds</span>
#       <div>
#         <div class="metric-value">0.7309523809523809</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:73.10%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.7514444444444445</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill rf-bar" style="width:75.14%"></div></div></div>
#       </div>
#     </div>
#   </div>
#
#   <!-- XGBoost -->
#   <div class="model-block">
#     <div class="model-header">
#       <span class="model-dot xgb-dot"></span>
#       <span class="model-name">XGBoost</span>
#     </div>
#     <div class="header-row">
#       <span class="col-head">Folds</span>
#       <span class="col-head">Accuracy</span>
#       <span class="col-head">ROC-AUC</span>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">0 folds</span>
#       <span class="na-tag">N/A</span>
#       <div>
#         <div class="metric-value">0.7055555555555555</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:70.56%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">5 folds</span>
#       <div>
#         <div class="metric-value">0.6672413793103449</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:66.72%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.5993932748538011</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:59.94%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">10 folds</span>
#       <div>
#         <div class="metric-value">0.7457142857142858</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:74.57%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.7146666666666667</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill xgb-bar" style="width:71.47%"></div></div></div>
#       </div>
#     </div>
#   </div>
#
#   <!-- SVM -->
#   <div class="model-block">
#     <div class="model-header">
#       <span class="model-dot svm-dot"></span>
#       <span class="model-name">SVM</span>
#     </div>
#     <div class="header-row">
#       <span class="col-head">Folds</span>
#       <span class="col-head">Accuracy</span>
#       <span class="col-head">ROC-AUC</span>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">0 folds</span>
#       <span class="na-tag">N/A</span>
#       <div>
#         <div class="metric-value">0.7166666666666667</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:71.67%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">5 folds</span>
#       <div>
#         <div class="metric-value">0.7593596059113301</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:75.94%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.7639766081871345</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:76.40%"></div></div></div>
#       </div>
#     </div>
#     <div class="fold-row">
#       <span class="fold-label">10 folds</span>
#       <div>
#         <div class="metric-value">0.7880952380952382</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:78.81%"></div></div></div>
#       </div>
#       <div>
#         <div class="metric-value">0.8075555555555555</div>
#         <div class="bar-container"><div class="bar-track"><div class="bar-fill svm-bar" style="width:80.76%"></div></div></div>
#       </div>
#     </div>
#   </div>
#
#   <div style="font-size: 11px; color: var(--color-text-tertiary); margin-top: 0.5rem;">0-fold rows report ROC-AUC only.</div>
# </div>

# %% [markdown]
# Random Forest

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/text_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns (removes text, IDs, etc.)
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Ensure label exists
if "label" not in df.columns:
    raise ValueError("Label column not found! Rename it to 'label'.")

# Separate features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Train-Test Split
# =========================
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# =========================
# 4️⃣ Scaling (optional for RF, but okay to keep)
# =========================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# =========================
# 5️⃣ Random Forest Model
# =========================
model = RandomForestClassifier(
    n_estimators=400,
    class_weight="balanced",
    random_state=42
)

model.fit(X_train, y_train)

# =========================
# 6️⃣ Predictions
# =========================
THRESHOLD = 0.40  # adjust if needed

y_prob = model.predict_proba(X_test)[:, 1]
y_pred = (y_prob > THRESHOLD).astype(int)

print("\nPredicted distribution:", np.bincount(y_pred))
print("Actual distribution:", np.bincount(y_test))

# =========================
# 7️⃣ Evaluation
# =========================
print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

roc = roc_auc_score(y_test, y_prob)
print("ROC-AUC Score:", roc)
# Out:
# Dataset shape: (141, 778)
# Class distribution: [99 42]
#
# Predicted distribution: [27  2]
# Actual distribution: [20  9]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.95      0.81        20
#            1       0.50      0.11      0.18         9
#
#     accuracy                           0.69        29
#    macro avg       0.60      0.53      0.50        29
# weighted avg       0.64      0.69      0.61        29
#
# ROC-AUC Score: 0.7333333333333333

# %% [markdown]
# Random Forest with 5 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/text_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================
# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Check label
if "label" not in df.columns:
    raise ValueError("Label column not found! Rename it to 'label'.")

# Split features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Stratified K-Fold
# =========================
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40
fold = 1

for train_idx, test_idx in skf.split(X, y):

    print(f"\n========== Fold {fold} ==========")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling (optional for RF)
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ Random Forest Model
    # =========================
    model = RandomForestClassifier(
        n_estimators=400,
        class_weight="balanced",
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 6️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    print("Predicted distribution:", np.bincount(y_pred))
    print("Actual distribution:", np.bincount(y_test))

    print(classification_report(y_test, y_pred, zero_division=0))

    acc = np.mean(y_pred == y_test)
    roc = roc_auc_score(y_test, y_prob)

    print("Fold Accuracy:", acc)
    print("Fold ROC-AUC:", roc)

    accuracies.append(acc)
    roc_scores.append(roc)

    fold += 1

# =========================
# 7️⃣ Final Results
# =========================
print("\n==============================")
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("==============================")
# Out:
# Dataset shape: (141, 778)
# Class distribution: [99 42]
#
# ========== Fold 1 ==========
# Predicted distribution: [28  1]
# Actual distribution: [20  9]
#               precision    recall  f1-score   support
#
#            0       0.68      0.95      0.79        20
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.66        29
#    macro avg       0.34      0.47      0.40        29
# weighted avg       0.47      0.66      0.55        29
#
# Fold Accuracy: 0.6551724137931034
# Fold ROC-AUC: 0.46944444444444444
#
# ========== Fold 2 ==========
# Predicted distribution: [27  1]
# Actual distribution: [20  8]
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85        20
#            1       1.00      0.12      0.22         8
#
#     accuracy                           0.75        28
#    macro avg       0.87      0.56      0.54        28
# ...

# %% [markdown]
# Random Forest with 10 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/text_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================
# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Check label
if "label" not in df.columns:
    raise ValueError("Label column not found! Rename it to 'label'.")

# Split features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Stratified K-Fold
# =========================
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40
fold = 1

for train_idx, test_idx in skf.split(X, y):

    print(f"\n========== Fold {fold} ==========")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling (optional for RF)
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ Random Forest Model
    # =========================
    model = RandomForestClassifier(
        n_estimators=400,
        class_weight="balanced",
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 6️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    print("Predicted distribution:", np.bincount(y_pred))
    print("Actual distribution:", np.bincount(y_test))

    print(classification_report(y_test, y_pred, zero_division=0))

    acc = np.mean(y_pred == y_test)
    roc = roc_auc_score(y_test, y_prob)

    print("Fold Accuracy:", acc)
    print("Fold ROC-AUC:", roc)

    accuracies.append(acc)
    roc_scores.append(roc)

    fold += 1

# =========================
# 7️⃣ Final Results
# =========================
print("\n==============================")
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("==============================")
# Out:
# Dataset shape: (141, 778)
# Class distribution: [99 42]
#
# ========== Fold 1 ==========
# Predicted distribution: [15]
# Actual distribution: [10  5]
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80        10
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.67        15
#    macro avg       0.33      0.50      0.40        15
# weighted avg       0.44      0.67      0.53        15
#
# Fold Accuracy: 0.6666666666666666
# Fold ROC-AUC: 0.22000000000000003
#
# ========== Fold 2 ==========
# Predicted distribution: [13  1]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.69      0.90      0.78        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.64        14
#    macro avg       0.35      0.45      0.39        14
# ...

# %% [markdown]
# XGBoost

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score
from xgboost import XGBClassifier

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/text_features_updated.csv")

print("Original columns:", df.columns)

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Check label column
if "label" not in df.columns:
    raise ValueError("Label column not found! Rename it to 'label'.")

# Separate features and labels
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Train-Test Split
# =========================
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# =========================
# 4️⃣ Feature Scaling
# =========================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# =========================
# 5️⃣ Handle Class Imbalance
# =========================
scale_pos_weight = len(y_train[y_train == 0]) / len(y_train[y_train == 1])

# =========================
# 6️⃣ XGBoost Model
# =========================
model = XGBClassifier(
    n_estimators=300,
    max_depth=4,
    learning_rate=0.05,
    scale_pos_weight=scale_pos_weight,
    eval_metric="logloss",
    random_state=42
)

model.fit(X_train, y_train)

# =========================
# 7️⃣ Predictions
# =========================
THRESHOLD = 0.40  # adjust for recall

y_prob = model.predict_proba(X_test)[:, 1]
y_pred = (y_prob > THRESHOLD).astype(int)

print("\nPredicted distribution:", np.bincount(y_pred))
print("Actual distribution:", np.bincount(y_test))

# =========================
# 8️⃣ Evaluation
# =========================
print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

roc = roc_auc_score(y_test, y_prob)
print("ROC-AUC Score:", roc)
# Out:
# Original columns: Index(['participant_id', 'word_count', 'sentence_count', 'avg_sentence_length',
#        'first_person_ratio', 'negation_count', 'uncertainty_count',
#        'type_token_ratio', 'mean_pause', 'max_pause',
#        ...
#        'sbert_std_375', 'sbert_std_376', 'sbert_std_377', 'sbert_std_378',
#        'sbert_std_379', 'sbert_std_380', 'sbert_std_381', 'sbert_std_382',
#        'sbert_std_383', 'label'],
#       dtype='str', length=779)
# Dataset shape: (141, 778)
# Class distribution: [99 42]
#
# Predicted distribution: [26  3]
# Actual distribution: [20  9]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.95      0.83        20
#            1       0.67      0.22      0.33         9
#
#     accuracy                           0.72        29
#    macro avg       0.70      0.59      0.58        29
# weighted avg       0.71      0.72      0.67        29
#
# ROC-AUC Score: 0.7055555555555555

# %% [markdown]
# XGBoost 5 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score
from xgboost import XGBClassifier

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/text_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Check label
if "label" not in df.columns:
    raise ValueError("Label column not found! Rename it to 'label'.")

# Split features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Stratified K-Fold Setup
# =========================
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40
fold = 1

for train_idx, test_idx in skf.split(X, y):

    print(f"\n========== Fold {fold} ==========")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ Handle Class Imbalance
    # =========================
    scale_pos_weight = len(y_train[y_train == 0]) / len(y_train[y_train == 1])

    # =========================
    # 6️⃣ XGBoost Model
    # =========================
    model = XGBClassifier(
        n_estimators=300,
        max_depth=4,
        learning_rate=0.05,
        scale_pos_weight=scale_pos_weight,
        eval_metric="logloss",
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 7️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    print("Predicted distribution:", np.bincount(y_pred))
    print("Actual distribution:", np.bincount(y_test))

    print(classification_report(y_test, y_pred, zero_division=0))

    acc = np.mean(y_pred == y_test)
    roc = roc_auc_score(y_test, y_prob)

    print("Fold Accuracy:", acc)
    print("Fold ROC-AUC:", roc)

    accuracies.append(acc)
    roc_scores.append(roc)

    fold += 1

# =========================
# 8️⃣ Final Results
# =========================
print("\n==============================")
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("==============================")
# Out:
# Dataset shape: (141, 778)
# Class distribution: [99 42]
#
# ========== Fold 1 ==========
# Predicted distribution: [22  7]
# Actual distribution: [20  9]
#               precision    recall  f1-score   support
#
#            0       0.68      0.75      0.71        20
#            1       0.29      0.22      0.25         9
#
#     accuracy                           0.59        29
#    macro avg       0.48      0.49      0.48        29
# weighted avg       0.56      0.59      0.57        29
#
# Fold Accuracy: 0.5862068965517241
# Fold ROC-AUC: 0.5333333333333333
#
# ========== Fold 2 ==========
# Predicted distribution: [24  4]
# Actual distribution: [20  8]
#               precision    recall  f1-score   support
#
#            0       0.71      0.85      0.77        20
#            1       0.25      0.12      0.17         8
#
#     accuracy                           0.64        28
#    macro avg       0.48      0.49      0.47        28
# ...

# %% [markdown]
# XGBoost 10 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score
from xgboost import XGBClassifier

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/text_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Check label
if "label" not in df.columns:
    raise ValueError("Label column not found! Rename it to 'label'.")

# Split features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Stratified K-Fold Setup
# =========================
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40
fold = 1

for train_idx, test_idx in skf.split(X, y):

    print(f"\n========== Fold {fold} ==========")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ Handle Class Imbalance
    # =========================
    scale_pos_weight = len(y_train[y_train == 0]) / len(y_train[y_train == 1])

    # =========================
    # 6️⃣ XGBoost Model
    # =========================
    model = XGBClassifier(
        n_estimators=300,
        max_depth=4,
        learning_rate=0.05,
        scale_pos_weight=scale_pos_weight,
        eval_metric="logloss",
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 7️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    print("Predicted distribution:", np.bincount(y_pred))
    print("Actual distribution:", np.bincount(y_test))

    print(classification_report(y_test, y_pred, zero_division=0))

    acc = np.mean(y_pred == y_test)
    roc = roc_auc_score(y_test, y_prob)

    print("Fold Accuracy:", acc)
    print("Fold ROC-AUC:", roc)

    accuracies.append(acc)
    roc_scores.append(roc)

    fold += 1

# =========================
# 8️⃣ Final Results
# =========================
print("\n==============================")
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("==============================")
# Out:
# Dataset shape: (141, 778)
# Class distribution: [99 42]
#
# ========== Fold 1 ==========
# Predicted distribution: [12  3]
# Actual distribution: [10  5]
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        10
#            1       0.33      0.20      0.25         5
#
#     accuracy                           0.60        15
#    macro avg       0.50      0.50      0.49        15
# weighted avg       0.56      0.60      0.57        15
#
# Fold Accuracy: 0.6
# Fold ROC-AUC: 0.4800000000000001
#
# ========== Fold 2 ==========
# Predicted distribution: [10  4]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        10
#            1       0.50      0.50      0.50         4
#
#     accuracy                           0.71        14
#    macro avg       0.65      0.65      0.65        14
# weighted avg       0.71      0.71      0.71        14
#
# ...

# %% [markdown]
# SVM

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/text_features_updated.csv")

print("Original columns:", df.columns)

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Check label column
if "label" not in df.columns:
    raise ValueError("Label column not found! Rename it to 'label'.")

# Separate features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Train-Test Split
# =========================
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# =========================
# 4️⃣ Scaling (VERY IMPORTANT for SVM)
# =========================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# =========================
# 5️⃣ SVM Model
# =========================
model = SVC(
    kernel='rbf',
    C=1.0,
    gamma='scale',
    probability=True,
    class_weight='balanced',
    random_state=42
)

model.fit(X_train, y_train)

# =========================
# 6️⃣ Predictions
# =========================
THRESHOLD = 0.40  # adjust for better recall

y_prob = model.predict_proba(X_test)[:, 1]
y_pred = (y_prob > THRESHOLD).astype(int)

print("\nPredicted distribution:", np.bincount(y_pred))
print("Actual distribution:", np.bincount(y_test))

# =========================
# 7️⃣ Evaluation
# =========================
print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

roc = roc_auc_score(y_test, y_prob)
print("ROC-AUC Score:", roc)
# Out:
# Original columns: Index(['participant_id', 'word_count', 'sentence_count', 'avg_sentence_length',
#        'first_person_ratio', 'negation_count', 'uncertainty_count',
#        'type_token_ratio', 'mean_pause', 'max_pause',
#        ...
#        'sbert_std_375', 'sbert_std_376', 'sbert_std_377', 'sbert_std_378',
#        'sbert_std_379', 'sbert_std_380', 'sbert_std_381', 'sbert_std_382',
#        'sbert_std_383', 'label'],
#       dtype='str', length=779)
# Dataset shape: (141, 778)
# Class distribution: [99 42]
#
# Predicted distribution: [21  8]
# Actual distribution: [20  9]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83        20
#            1       0.62      0.56      0.59         9
#
#     accuracy                           0.76        29
#    macro avg       0.72      0.70      0.71        29
# weighted avg       0.75      0.76      0.75        29
#
# ROC-AUC Score: 0.7166666666666667

# %% [markdown]
# SVM 5 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/text_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Check label column
if "label" not in df.columns:
    raise ValueError("Label column not found! Rename it to 'label'.")

# Separate features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Stratified K-Fold
# =========================
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40
fold = 1

for train_idx, test_idx in skf.split(X, y):

    print(f"\n========== Fold {fold} ==========")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling (VERY IMPORTANT for SVM)
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ SVM Model
    # =========================
    model = SVC(
        kernel='rbf',
        C=1.0,
        gamma='scale',
        probability=True,
        class_weight='balanced',
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 6️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    print("Predicted distribution:", np.bincount(y_pred))
    print("Actual distribution:", np.bincount(y_test))

    print(classification_report(y_test, y_pred, zero_division=0))

    acc = np.mean(y_pred == y_test)
    roc = roc_auc_score(y_test, y_prob)

    print("Fold Accuracy:", acc)
    print("Fold ROC-AUC:", roc)

    accuracies.append(acc)
    roc_scores.append(roc)

    fold += 1

# =========================
# 7️⃣ Final Results
# =========================
print("\n==============================")
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("==============================")
# Out:
# Dataset shape: (141, 778)
# Class distribution: [99 42]
#
# ========== Fold 1 ==========
# Predicted distribution: [21  8]
# Actual distribution: [20  9]
#               precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78        20
#            1       0.50      0.44      0.47         9
#
#     accuracy                           0.69        29
#    macro avg       0.63      0.62      0.63        29
# weighted avg       0.68      0.69      0.68        29
#
# Fold Accuracy: 0.6896551724137931
# Fold ROC-AUC: 0.5277777777777778
#
# ========== Fold 2 ==========
# Predicted distribution: [23  5]
# Actual distribution: [20  8]
#               precision    recall  f1-score   support
#
#            0       0.83      0.95      0.88        20
#            1       0.80      0.50      0.62         8
#
#     accuracy                           0.82        28
#    macro avg       0.81      0.72      0.75        28
# ...

# %% [markdown]
# SVM 10 Folds

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, roc_auc_score

# =========================
# 1️⃣ Load Dataset
# =========================
df = pd.read_csv("../data/text_features_updated.csv")

# =========================
# 2️⃣ Clean Dataset
# =========================

# Keep only numeric columns
df = df.select_dtypes(include=["int64", "float64"])

# Drop missing values
df = df.dropna()

# Check label column
if "label" not in df.columns:
    raise ValueError("Label column not found! Rename it to 'label'.")

# Separate features and label
X = df.drop("label", axis=1).values
y = df["label"].values

print("Dataset shape:", X.shape)
print("Class distribution:", np.bincount(y))

# =========================
# 3️⃣ Stratified K-Fold
# =========================
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

accuracies = []
roc_scores = []

THRESHOLD = 0.40
fold = 1

for train_idx, test_idx in skf.split(X, y):

    print(f"\n========== Fold {fold} ==========")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # 4️⃣ Scaling (VERY IMPORTANT for SVM)
    # =========================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # 5️⃣ SVM Model
    # =========================
    model = SVC(
        kernel='rbf',
        C=1.0,
        gamma='scale',
        probability=True,
        class_weight='balanced',
        random_state=42
    )

    model.fit(X_train, y_train)

    # =========================
    # 6️⃣ Predictions
    # =========================
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob > THRESHOLD).astype(int)

    print("Predicted distribution:", np.bincount(y_pred))
    print("Actual distribution:", np.bincount(y_test))

    print(classification_report(y_test, y_pred, zero_division=0))

    acc = np.mean(y_pred == y_test)
    roc = roc_auc_score(y_test, y_prob)

    print("Fold Accuracy:", acc)
    print("Fold ROC-AUC:", roc)

    accuracies.append(acc)
    roc_scores.append(roc)

    fold += 1

# =========================
# 7️⃣ Final Results
# =========================
print("\n==============================")
print("Average Accuracy:", np.mean(accuracies))
print("Average ROC-AUC:", np.mean(roc_scores))
print("==============================")
# Out:
# Dataset shape: (141, 778)
# Class distribution: [99 42]
#
# ========== Fold 1 ==========
# Predicted distribution: [11  4]
# Actual distribution: [10  5]
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76        10
#            1       0.50      0.40      0.44         5
#
#     accuracy                           0.67        15
#    macro avg       0.61      0.60      0.60        15
# weighted avg       0.65      0.67      0.66        15
#
# Fold Accuracy: 0.6666666666666666
# Fold ROC-AUC: 0.32000000000000006
#
# ========== Fold 2 ==========
# Predicted distribution: [10  4]
# Actual distribution: [10  4]
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        10
#            1       0.75      0.75      0.75         4
#
#     accuracy                           0.86        14
#    macro avg       0.82      0.82      0.82        14
# ...
